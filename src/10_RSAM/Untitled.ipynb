# %%
import matplotlib.pyplot as plt
plt.plot(1,1)
plt.ylabel(r'$D_{RS}$ ($cm^{2}$)')
# Out:
# Text(0, 0.5, '$D_{RS}$ ($cm^{2}$)')

# %%
measurement = 'DRS'
x="{2}"
units = r"($cm{2}$)"
units = f"(cm\N{SUPERSCRIPT TWO})"
print(units)
if measurement[1]=='R':
    subscript = "{%s}" % measurement[1:]
    measurement = f"${measurement[0]}_{subscript}$"
plt.plot(1,1)
plt.ylabel(measurement + units)
# Out:
# (cm²)
# Text(0, 0.5, '$D_{RS}$(cm²)')
